# %% [markdown]
# # IPS 2D Spectroscopy
#
# Slide-friendly variant of the 2D spectroscopy figure.

# %%
from echospec.figures import FigureVariant, apply_figure_style, save_figure
from echospec.figures.spectroscopy import finish_figure, polish_axes_for_variant

VARIANT = FigureVariant.PRESENTATION_IPS
apply_figure_style(VARIANT)

# %% [markdown]
# Use the same computed array as the paper figure, but prefer one clear color map, larger text, and fewer overlays.

# %%
# Example pattern:
# fig, ax = plt.subplots()
# mesh = ax.pcolormesh(detuning_mhz, amplitude_mhz, population, shading="auto")
# fig.colorbar(mesh, ax=ax, label="Population")
# polish_axes_for_variant(ax, variant=VARIANT, xlabel="Detuning (MHz)", ylabel="Drive (MHz)")
# finish_figure(fig, variant=VARIANT)
# save_figure(fig, "2d_spectroscopy", variant=VARIANT)
