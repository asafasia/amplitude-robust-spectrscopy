# %% [markdown]
# # IPS Figure Template
#
# Use this notebook as the starting point for slide-friendly figure variants.

# %%
from echospec.figures import FigureVariant, apply_figure_style, save_figure

VARIANT = FigureVariant.PRESENTATION_IPS
apply_figure_style(VARIANT)

# %% [markdown]
# Load or compute the same data used by the paper figure, then simplify labels, annotations, and panel count for the presentation.

# %%
# fig = make_your_figure(...)
# save_figure(fig, "figure_name", variant=VARIANT)
