# %% [markdown]
# # IPS Pulse Profiles
#
# Slide-friendly pulse-profile figures.

# %%
from echospec.figures import FigureVariant, apply_figure_style, save_figure
from echospec.figures.spectroscopy import finish_figure, polish_axes_for_variant

VARIANT = FigureVariant.PRESENTATION_IPS
apply_figure_style(VARIANT)

# %% [markdown]
# Keep pulse plots visually direct: one message per panel, large labels, and minimal secondary notation.

# %%
# Example pattern:
# fig, ax = plt.subplots()
# ax.plot(time_us, pulse)
# polish_axes_for_variant(ax, variant=VARIANT, xlabel="Time (us)", ylabel="Amplitude")
# finish_figure(fig, variant=VARIANT)
# save_figure(fig, "pulse_profile", variant=VARIANT)
