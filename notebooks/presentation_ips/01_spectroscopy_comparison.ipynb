# %% [markdown]
# # IPS Spectroscopy Comparison
#
# Slide-friendly variant of the spectroscopy comparison figure.

# %%
from echospec.figures import FigureVariant, apply_figure_style, save_figure
from echospec.figures.spectroscopy import finish_figure, polish_axes_for_variant

VARIANT = FigureVariant.PRESENTATION_IPS
apply_figure_style(VARIANT)

# %% [markdown]
# Reuse the same data source as the paper notebook, then reduce detail for the IPS slide.

# %%
# Example pattern:
# fig, ax = plt.subplots()
# ax.plot(detuning_mhz, signal)
# polish_axes_for_variant(ax, variant=VARIANT, xlabel="Detuning (MHz)", ylabel="Signal")
# finish_figure(fig, variant=VARIANT)
# save_figure(fig, "spectroscopy_comparison", variant=VARIANT)
